# %%
x = 2 + 2

print(x)
# Out:
# 4

# %% [markdown]
# # What is a markdown?
#
# It's formatted text

# %% [markdown]
# Write a function that takes a, b, c and returns a list of solutions for $a*x^2 + b*x + c = 0$

# %%
import math

def compute_quadratic_equation_solutions(a, b, c):
  d = b ** 2 - 4 * a * c

  if d > 0:
    return [(-b + math.sqrt(d)) / (2 * a), (-b - math.sqrt(d)) / (2 * a)]
  elif d == 0:
    return [-b / (2 * a)]
  else:
    return []

print(compute_quadratic_equation_solutions(2, -6, 4))
print(compute_quadratic_equation_solutions(2, -6, 8))
print(compute_quadratic_equation_solutions(2, 8, 8))
# Out:
# [2.0, 1.0]
# []
# [-2.0]
